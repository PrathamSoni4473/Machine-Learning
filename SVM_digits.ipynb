# %% [markdown]
# <a href="https://colab.research.google.com/github/PrathamSoni4473/Machine-Learning/blob/main/SVM_digits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn import tree
import graphviz
from sklearn.datasets import load_digits
from sklearn.svm import SVC

# %%
digit = load_digits()
x = digit.data
y = digit.target

x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=100,test_size=0.2)

clf = SVC(C=10,kernel='rbf')
clf.fit(x_train,y_train)
y_pred = clf.predict(x_test)
print('Training Score :',clf.score(x_train,y_train))
print('Testing Score :',clf.score(x_test,y_test))

cm = confusion_matrix(y_test,y_pred)
sns.heatmap(cm,annot=True)
# Out:
# Training Score : 1.0
# Testing Score : 1.0

# %%
clf = SVC(kernel='linear')
clf.fit(x_train,y_train)
y_pred = clf.predict(x_test)
print('Training Score :',clf.score(x_train,y_train))
print('Testing Score :',clf.score(x_test,y_test))

cm = confusion_matrix(y_test,y_pred)
sns.heatmap(cm,annot=True)
# Out:
# Training Score : 1.0
# Testing Score : 0.9861111111111112
